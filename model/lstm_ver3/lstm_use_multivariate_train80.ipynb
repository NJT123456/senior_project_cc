# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from keras.layers import Dropout
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error as mape,mean_absolute_error as mae
from keras import optimizers

# %% [markdown]
# # Prepare Data

# %%
cloud_cover = pd.read_csv('../prophet_ver2/mergefile_drop_na.csv',skipinitialspace = True)
cloud_cover = cloud_cover.rename(columns={"timestamp":"DateTime"})
cloud_cover
# Out:
#                  DateTime       Eeg  Temperature       RH  Windspeed  \
# 0     2021-11-16 11:15:00  389.3058      29.3306  68.9674     1.7412
# 1     2021-11-16 11:20:00  386.4714      29.2626  69.6372     1.7202
# 2     2021-11-16 11:25:00  362.6794      29.2746  70.6488     1.7378
# 3     2021-11-16 11:30:00  304.7228      29.2650  70.6084     1.6944
# 4     2021-11-16 11:35:00  297.6544      29.2550  70.7396     1.7838
# ...                   ...       ...          ...      ...        ...
# 2975  2021-12-16 13:40:00  667.8462      32.0638  38.0598     1.7466
# 2976  2021-12-16 13:45:00  655.7560      32.3906  37.1100     1.7442
# 2977  2021-12-16 13:50:00  647.5236      32.3444  37.1282     1.7116
# 2978  2021-12-16 13:55:00  635.4336      32.3944  37.2276     1.7612
# 2979  2021-12-16 14:00:00  623.2140      32.8780  36.3920     1.7566
#
#       cloud_cover
# 0        0.990000
# 1        0.989667
# 2        0.993667
# 3        0.987500
# 4        0.989000
# ...           ...
# 2975     0.185000
# 2976     0.182000
# 2977     0.180000
# 2978     0.169000
# 2979     0.147000
#
# [2980 rows x 6 columns]

# %%
def lags_train_test(datax, datay, data, lags):
	X, y = [], []
	for i in range(lags, len(data)):
		X.append(datax[i-lags:i])
		y.append(datay[i])
	return np.array(X), np.array(y)

# %%
def Xtrain_ytrain(train,test,lags):
    sc = MinMaxScaler()
    train_x = sc.fit_transform(train)
    sc1 = MinMaxScaler()
    train_y = sc1.fit_transform(train[['cloud_cover']])
    # train
    X_train, y_train = lags_train_test(train_x,train_y, train, lags)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
    print("X_train Shape :", X_train.shape)
    print("y_train Shape :", y_train.shape)

    #scale test
    columns = test[['Eeg','Temperature','RH','Windspeed','cloud_cover']]
    dataset_total = pd.concat(([train,test]), axis=0)
    inputs = dataset_total[len(dataset_total) - len(test) - lags:].values
    inputs = pd.DataFrame(inputs, columns=columns.columns)
    test_x = sc.transform(inputs)
    test_y = sc1.transform(inputs[['cloud_cover']])
    # test
    X_test, y_test = lags_train_test(test_x,test_y, inputs, lags)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))
    print("X_test Shape : ", X_test.shape)
    print("y_test Shape : ", y_test.shape)
    return X_train, y_train, X_test, y_test, sc1

# %%
def plot_curve(history):
    # loss curves
    fig1 = plt.figure(figsize=[8,6])
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(loss) + 1)

    plt.plot(epochs, loss, 'orange', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

# %%
def plot_curve(history):
    # loss curves
    fig1 = plt.figure(figsize=[8,6])
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(loss) + 1)

    plt.plot(epochs, loss, 'orange', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

# %%
def plot_test(train,pred):
    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(mode = 'lines', x = train['DateTime'], y = train['cloud_cover'], name = 'Train'))
    fig2.add_trace(go.Scatter(mode = 'lines', x = pred['DateTime'], y = pred['cloud_cover'], name = 'Actual'))
    fig2.add_trace(go.Scatter(mode = 'lines', x = pred['DateTime'], y = pred['LSTM'], name = 'Predict'))
    fig2.update_layout(
    autosize=True,
    height=600,
    title="LSTM Model",
    xaxis_title="Date",
    yaxis_title="Cloud cover",
    )


    fig2.update_layout(
        xaxis=dict(
            rangeselector=dict(
                buttons=list([
                    dict(count=1,
                        label="1.zoom",
                        step="hour",
                        stepmode="backward"),
                    dict(count=2,
                        label="2.zoom",
                        step="hour",
                        stepmode="backward"),
                    dict(count=3,
                        label="3.zoom",
                        step="day",
                        stepmode="backward"),              

                    dict(step="all")
                ])
            ),
            rangeslider=dict(
                visible=True
            ),
            type="date"
        )
    )

    fig2.show()

# %% [markdown]
# # Train/Test Model

# %%
train,test = train_test_split(cloud_cover, train_size=0.8, shuffle=False)
print('Train Shape', train.shape)
print('Test Shape', test.shape)
# Out:
# Train Shape (2384, 6)
# Test Shape (596, 6)

# %%
train
# Out:
#                  DateTime       Eeg  Temperature       RH  Windspeed  \
# 0     2021-11-16 11:15:00  389.3058      29.3306  68.9674     1.7412
# 1     2021-11-16 11:20:00  386.4714      29.2626  69.6372     1.7202
# 2     2021-11-16 11:25:00  362.6794      29.2746  70.6488     1.7378
# 3     2021-11-16 11:30:00  304.7228      29.2650  70.6084     1.6944
# 4     2021-11-16 11:35:00  297.6544      29.2550  70.7396     1.7838
# ...                   ...       ...          ...      ...        ...
# 2379  2021-12-10 14:45:00  489.3422      30.9634  47.6566     1.7682
# 2380  2021-12-10 14:50:00  492.3882      30.8892  47.8534     1.8098
# 2381  2021-12-10 14:55:00  469.3254      30.9140  47.4738     1.7394
# 2382  2021-12-10 15:00:00  459.6700      30.7786  47.5446     1.6592
# 2383  2021-12-10 15:05:00  442.6758      30.8698  47.9222     1.7448
#
#       cloud_cover
# 0        0.990000
# 1        0.989667
# 2        0.993667
# 3        0.987500
# 4        0.989000
# ...           ...
# 2379     0.585000
# 2380     0.582000
# 2381     0.453000
# 2382     0.595000
# 2383     0.642000
#
# [2384 rows x 6 columns]

# %%
test
# Out:
#                  DateTime       Eeg  Temperature       RH  Windspeed  \
# 2384  2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 2385  2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2386  2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 2387  2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 2388  2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ...                   ...       ...          ...      ...        ...
# 2975  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 2976  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 2977  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 2978  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 2979  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#       cloud_cover
# 2384        0.601
# 2385        0.654
# 2386        0.588
# 2387        0.577
# 2388        0.554
# ...           ...
# 2975        0.185
# 2976        0.182
# 2977        0.180
# 2978        0.169
# 2979        0.147
#
# [596 rows x 6 columns]

# %%
train = train.set_index('DateTime')
test = test.set_index('DateTime')

# %% [markdown]
# ## Lag 5

# %%
# X_train, y_train, X_test and y_test
X_train, y_train, X_test, y_test, sc = Xtrain_ytrain(train,test,5)
# Out:
# X_train Shape : (2379, 5, 5)
# y_train Shape : (2379, 1)
# X_test Shape :  (596, 5, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Add frist layer: units = 100

# %%
model_1 = Sequential()
model_1.add(LSTM(units = 100, return_sequences = False, input_shape = (X_train.shape[1],X_train.shape[2])))
model_1.add(Dense(units = 1))
model_1.compile(optimizer = 'adam', loss = 'mean_squared_error')
hist = model_1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 4s 19ms/step - loss: 0.0533 - val_loss: 0.0115
# Epoch 2/20
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0111
# Epoch 3/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0106
# Epoch 4/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 5/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 6/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 7/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 8/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 9/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 10/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 11/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 12/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0068
# Epoch 13/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 14/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 15/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 16/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 17/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0074
# Epoch 18/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 19/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 20/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0067

# %%
plot_curve(hist)

# %%
predict_scaled = model_1.predict(X_test)
predict = sc.inverse_transform(predict_scaled)
predict
# Out:
# 19/19 [==============================] - 1s 3ms/step
# array([[0.63466614],
#        [0.596229  ],
#        [0.63583267],
#        [0.5792068 ],
#        [0.55917406],
#        [0.54776263],
#        [0.5366616 ],
#        [0.51533324],
#        [0.48886395],
#        [0.56100374],
#        [0.5733995 ],
#        [0.44925398],
#        [0.47514358],
#        [0.31427744],
#        [0.30587894],
#        [0.35207224],
#        [0.29649693],
#        [0.21620882],
#        [0.26855522],
#        [0.22232562],
#        [0.18450896],
#        [0.15750916],
#        [0.67324936],
#        [0.87148625],
#        [0.91082317],
#        [0.81349915],
#        [0.83979166],
#        [0.8021729 ],
#        [0.84151113],
#        [0.8600919 ],
#        [0.7780339 ],
#        [0.7757313 ],
#        [0.83964676],
#        [0.8810695 ],
#        [0.71263003],
#        [0.6677651 ],
#        [0.63075364],
#        [0.6572456 ],
#        [0.704415  ],
#        [0.5765588 ],
#        [0.57267094],
#        [0.60598224],
#        [0.56367254],
#        [0.6345172 ],
#        [0.6579656 ],
#        [0.71125364],
#        [0.855392  ],
#        [0.88530284],
#        [0.8810231 ],
#        [0.8944704 ],
#        [0.8975529 ],
#        [0.8808487 ],
#        [0.87979156],
#        [0.8997383 ],
#        [0.9059912 ],
#        [0.8231039 ],
#        [0.84631866],
#        [0.8755535 ],
#        [0.5730371 ],
#        [0.56617546],
#        [0.62201023],
#        [0.5071583 ],
#        [0.6971691 ],
#        [0.55415726],
#        [0.57435465],
#        [0.4123865 ],
#        [0.30674046],
#        [0.28628862],
#        [0.3096861 ],
#        [0.40301675],
#        [0.41891524],
#        [0.41091445],
#        [0.44408154],
#        [0.44893503],
#        [0.44298086],
#        [0.44892746],
#        [0.4274835 ],
#        [0.54142404],
#        [0.50415474],
#        [0.5364159 ],
#        [0.4426851 ],
#        [0.41128194],
#        [0.39729   ],
#        [0.3482027 ],
#        [0.4170773 ],
#        [0.48888066],
#        [0.40413848],
#        [0.36884692],
#        [0.36074772],
#        [0.35545588],
#        [0.46364748],
#        [0.34716076],
#        [0.2582169 ],
#        [0.29762888],
#        [0.30242836],
#        [0.2307234 ],
#        [0.29253593],
#        [0.16458133],
#        [0.1624307 ],
#        [0.16560826],
#        [0.17992443],
#        [0.17639065],
#        [0.21303846],
#        [0.17785943],
#        [0.36922175],
#        [0.18939659],
#        [0.17294854],
#        [0.16721795],
#        [0.14706394],
#        [0.18819638],
#        [0.16501312],
#        [0.32424843],
#        [0.22724964],
#        [0.3847369 ],
#        [0.43917042],
#        [0.53376365],
#        [0.4178437 ],
#        [0.5778365 ],
#        [0.6031649 ],
#        [0.3859053 ],
#        [0.4405509 ],
#        [0.67312706],
#        [0.66536975],
#        [0.58581775],
#        [0.66659564],
#        [0.87051135],
#        [0.8329998 ],
#        [0.8185456 ],
#        [0.8732255 ],
#        [0.82170665],
#        [0.8356127 ],
#        [0.7793894 ],
#        [0.79699516],
#        [0.8314212 ],
#        [0.8389176 ],
#        [0.8650691 ],
#        [0.81426173],
#        [0.66066927],
#        [0.65480834],
#        [0.7204174 ],
#        [0.5899238 ],
#        [0.54576373],
#        [0.56573296],
#        [0.6207302 ],
#        [0.6594302 ],
#        [0.69838333],
#        [0.6639271 ],
#        [0.6757774 ],
#        [0.7214878 ],
#        [0.7990622 ],
#        [0.823413  ],
#        [0.8334815 ],
#        [0.8407169 ],
#        [0.84684557],
#        [0.8712378 ],
#        [0.89592886],
#        [0.9026399 ],
#        [0.8003847 ],
#        [0.8933897 ],
#        [0.8211456 ],
#        [0.8294119 ],
#        [0.8230211 ],
#        [0.84442407],
#        [0.8247298 ],
#        [0.7749717 ],
#        [0.59916717],
#        [0.59771913],
#        [0.64025754],
#        [0.5326246 ],
#        [0.5242419 ],
#        [0.44976872],
#        [0.5406591 ],
#        [0.5908337 ],
#        [0.56295407],
#        [0.5828353 ],
#        [0.51257753],
#        [0.66258276],
#        [0.6287804 ],
#        [0.62389916],
#        [0.64395106],
#        [0.5942478 ],
#        [0.5175641 ],
#        [0.5101025 ],
#        [0.54593396],
#        [0.58477753],
#        [0.5497659 ],
#        [0.5522102 ],
#        [0.6070194 ],
#        [0.6075192 ],
#        [0.4994022 ],
#        [0.4751654 ],
#        [0.46183008],
#        [0.4108069 ],
#        [0.5959574 ],
#        [0.46685386],
#        [0.3793701 ],
#        [0.47984025],
#        [0.5265096 ],
#        [0.548941  ],
#        [0.60087484],
#        [0.5857088 ],
#        [0.5136464 ],
#        [0.47849545],
#        [0.6195042 ],
#        [0.49677798],
#        [0.45323682],
#        [0.56654286],
#        [0.65764683],
#        [0.62376297],
#        [0.57278633],
#        [0.56376696],
#        [0.5302723 ],
#        [0.5863125 ],
#        [0.6173541 ],
#        [0.5898325 ],
#        [0.57537276],
#        [0.5485711 ],
#        [0.46335414],
#        [0.67860335],
#        [0.6646182 ],
#        [0.65032214],
#        [0.60187054],
#        [0.7083374 ],
#        [0.6859833 ],
#        [0.7295086 ],
#        [0.76466596],
#        [0.7567308 ],
#        [0.76606697],
#        [0.77507806],
#        [0.8557626 ],
#        [0.9563942 ],
#        [0.91019285],
#        [0.8955723 ],
#        [0.9235467 ],
#        [0.9629315 ],
#        [0.9542443 ],
#        [0.9392134 ],
#        [0.96561193],
#        [0.97563523],
#        [0.9660894 ],
#        [0.97320396],
#        [0.93420494],
#        [0.90142465],
#        [0.92204535],
#        [0.9354123 ],
#        [0.9105439 ],
#        [0.89427406],
#        [0.9223605 ],
#        [0.8893997 ],
#        [0.84312195],
#        [0.88128895],
#        [0.87121487],
#        [0.8857055 ],
#        [0.8616633 ],
#        [0.8223105 ],
#        [0.82140005],
#        [0.8083647 ],
#        [0.7587076 ],
#        [0.76486814],
#        [0.7532331 ],
#        [0.67780554],
#        [0.6755405 ],
#        [0.3862248 ],
#        [0.3627309 ],
#        [0.35679477],
#        [0.34981012],
#        [0.38124385],
#        [0.4429491 ],
#        [0.39078987],
#        [0.58412695],
#        [0.6136919 ],
#        [0.48341128],
#        [0.5031629 ],
#        [0.43040636],
#        [0.39847085],
#        [0.4287231 ],
#        [0.43823913],
#        [0.35647273],
#        [0.37311321],
#        [0.4482475 ],
#        [0.4548923 ],
#        [0.47672048],
#        [0.501656  ],
#        [0.38886043],
#        [0.41211918],
#        [0.40190053],
#        [0.27307218],
#        [0.2247976 ],
#        [0.21858647],
#        [0.2613343 ],
#        [0.31105816],
#        [0.39021304],
#        [0.33378506],
#        [0.3644318 ],
#        [0.43501806],
#        [0.535267  ],
#        [0.52500075],
#        [0.23210526],
#        [0.18440326],
#        [0.19600281],
#        [0.21064125],
#        [0.23070131],
#        [0.21205324],
#        [0.18297888],
#        [0.19125712],
#        [0.1896625 ],
#        [0.22960985],
#        [0.21761645],
#        [0.14897992],
#        [0.13474149],
#        [0.12240904],
#        [0.1150215 ],
#        [0.12334093],
#        [0.1110592 ],
#        [0.12027246],
#        [0.12748632],
#        [0.12207609],
#        [0.11670745],
#        [0.10931529],
#        [0.1086889 ],
#        [0.11319012],
#        [0.13036014],
#        [0.14948161],
#        [0.13774674],
#        [0.11613547],
#        [0.12497849],
#        [0.10597879],
#        [0.12743719],
#        [0.12237664],
#        [0.11603336],
#        [0.11398683],
#        [0.11705681],
#        [0.13749266],
#        [0.12562785],
#        [0.13153006],
#        [0.13414194],
#        [0.12138189],
#        [0.13268542],
#        [0.15184407],
#        [0.13409136],
#        [0.14087817],
#        [0.14484897],
#        [0.14466406],
#        [0.11587867],
#        [0.04944567],
#        [0.02776676],
#        [0.05626768],
#        [0.05172922],
#        [0.05549248],
#        [0.0498201 ],
#        [0.04981097],
#        [0.04925195],
#        [0.04991686],
#        [0.06093246],
#        [0.05948161],
#        [0.06226629],
#        [0.07886362],
#        [0.08429217],
#        [0.09820455],
#        [0.0943343 ],
#        [0.09381653],
#        [0.0753375 ],
#        [0.08246927],
#        [0.09001411],
#        [0.06588192],
#        [0.06686284],
#        [0.07555608],
#        [0.0632598 ],
#        [0.0615485 ],
#        [0.06665676],
#        [0.06277531],
#        [0.05784266],
#        [0.06410091],
#        [0.05908222],
#        [0.05969654],
#        [0.05552496],
#        [0.05592097],
#        [0.05830242],
#        [0.0620192 ],
#        [0.07262812],
#        [0.0850428 ],
#        [0.07029483],
#        [0.06721052],
#        [0.06914151],
#        [0.05960435],
#        [0.06825558],
#        [0.07025772],
#        [0.08993783],
#        [0.09264961],
#        [0.10021006],
#        [0.11033524],
#        [0.33720243],
#        [0.58481294],
#        [0.40606678],
#        [0.46852684],
#        [0.5923017 ],
#        [0.5552207 ],
#        [0.566981  ],
#        [0.493453  ],
#        [0.5044633 ],
#        [0.46710312],
#        [0.50462687],
#        [0.4938367 ],
#        [0.4613971 ],
#        [0.4623155 ],
#        [0.46193215],
#        [0.43555614],
#        [0.5058643 ],
#        [0.42561072],
#        [0.5571665 ],
#        [0.5658352 ],
#        [0.4913862 ],
#        [0.51919043],
#        [0.64296764],
#        [0.5218988 ],
#        [0.5082669 ],
#        [0.53560156],
#        [0.5657058 ],
#        [0.562696  ],
#        [0.6174156 ],
#        [0.3647241 ],
#        [0.391493  ],
#        [0.33980817],
#        [0.30827454],
#        [0.34033895],
#        [0.34136668],
#        [0.39510024],
#        [0.41261825],
#        [0.40828753],
#        [0.33915028],
#        [0.36247855],
#        [0.44342947],
#        [0.13361391],
#        [0.07628798],
#        [0.063467  ],
#        [0.06931783],
#        [0.06959414],
#        [0.08877938],
#        [0.07769969],
#        [0.08876667],
#        [0.08654338],
#        [0.07364695],
#        [0.08660623],
#        [0.09217508],
#        [0.02462298],
#        [0.00969899],
#        [0.02465993],
#        [0.02760822],
#        [0.01834803],
#        [0.02155276],
#        [0.02678766],
#        [0.025934  ],
#        [0.02529165],
#        [0.03100371],
#        [0.03268188],
#        [0.03338878],
#        [0.04482352],
#        [0.05652433],
#        [0.05865741],
#        [0.06240761],
#        [0.05282024],
#        [0.04834666],
#        [0.05251855],
#        [0.0565095 ],
#        [0.04740992],
#        [0.05423018],
#        [0.04527675],
#        [0.05514187],
#        [0.06208551],
#        [0.05293733],
#        [0.07803592],
#        [0.06704104],
#        [0.06073429],
#        [0.07004629],
#        [0.08776252],
#        [0.06796128],
#        [0.06416873],
#        [0.06528364],
#        [0.05691317],
#        [0.05939114],
#        [0.09670577],
#        [0.07257134],
#        [0.07193498],
#        [0.07956195],
#        [0.08175601],
#        [0.09400014],
#        [0.12525204],
#        [0.10931459],
#        [0.06179136],
#        [0.04301621],
#        [0.03940753],
#        [0.05370762],
#        [0.0629982 ],
#        [0.05747546],
#        [0.04702666],
#        [0.04480736],
#        [0.04251501],
#        [0.04555234],
#        [0.04927693],
#        [0.05028791],
#        [0.05170434],
#        [0.06734594],
#        [0.07455339],
#        [0.09077343],
#        [0.08891015],
#        [0.08747608],
#        [0.09066815],
#        [0.09853431],
#        [0.08488806],
#        [0.09254605],
#        [0.08580147],
#        [0.08282244],
#        [0.08669362],
#        [0.08856941],
#        [0.08584169],
#        [0.08512884],
#        [0.06345128],
#        [0.05465529],
#        [0.06746251],
#        [0.0800267 ],
#        [0.06711475],
#        [0.07335703],
#        [0.06306164],
#        [0.06122116],
#        [0.05863602],
#        [0.07848067],
#        [0.21476689],
#        [0.23596208],
#        [0.22817725],
#        [0.211202  ],
#        [0.20563337],
#        [0.24135485],
#        [0.21799816],
#        [0.23351212],
#        [0.21329138],
#        [0.29151243],
#        [0.25217068],
#        [0.3036475 ],
#        [0.13669793],
#        [0.07620919],
#        [0.09242845],
#        [0.10573016],
#        [0.11880688],
#        [0.14572166],
#        [0.15110622],
#        [0.14915055],
#        [0.18644321],
#        [0.25535274],
#        [0.33227694],
#        [0.31898397],
#        [0.28781205],
#        [0.24841738],
#        [0.2851704 ],
#        [0.3099256 ],
#        [0.4247646 ],
#        [0.30435482],
#        [0.5475076 ],
#        [0.6857907 ],
#        [0.732382  ],
#        [0.78438354],
#        [0.26067674],
#        [0.17160892],
#        [0.19383243],
#        [0.15444174],
#        [0.15784559],
#        [0.14971444],
#        [0.14743413],
#        [0.13978042],
#        [0.1434999 ],
#        [0.1380016 ],
#        [0.1280773 ],
#        [0.12470614],
#        [0.14869551],
#        [0.15988566],
#        [0.16329244],
#        [0.15998137],
#        [0.16711766],
#        [0.1618215 ],
#        [0.1645919 ],
#        [0.16006242],
#        [0.13980006],
#        [0.15177958],
#        [0.16275837],
#        [0.16854565],
#        [0.16815308],
#        [0.16162606],
#        [0.16201493],
#        [0.16666895],
#        [0.17652619],
#        [0.18347014],
#        [0.17878199],
#        [0.1782227 ],
#        [0.1831754 ],
#        [0.17976847],
#        [0.17734693],
#        [0.16921212]], dtype=float32)

# %%
train0 = train.copy()
test0 = test.copy()

# %%
train0.reset_index(inplace=True)
test0.reset_index(inplace=True)

# %%
test0['LSTM'] = predict
test0
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.634666
# 1          0.654  0.596229
# 2          0.588  0.635833
# 3          0.577  0.579207
# 4          0.554  0.559174
# ..           ...       ...
# 591        0.185  0.178223
# 592        0.182  0.183175
# 593        0.180  0.179768
# 594        0.169  0.177347
# 595        0.147  0.169212
#
# [596 rows x 7 columns]

# %%
plot_test(train0,test0)

# %%
lstm_mae_error = mae(test0["cloud_cover"], test0["LSTM"])
lstm_mape_error = mape(test0["cloud_cover"], test0["LSTM"])
lstm_mse_error = mean_squared_error(test0['cloud_cover'], test0['LSTM'], squared=True)
lstm_rmse_error = mean_squared_error(test0["cloud_cover"], test0["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error)
print('MAPE Error :  %.5f'%lstm_mape_error)
print('MSE Error : %.5f'%lstm_mse_error)
print('RMSE Error :  %.5f'%lstm_rmse_error)
# Out:
# MAE Error :  0.04742
# MAPE Error :  0.17651
# MSE Error : 0.00663
# RMSE Error :  0.08140

# %% [markdown]
# ---

# %% [markdown]
# ## Lag 10

# %%
# X_train, y_train, X_test and y_test
X_train1, y_train1, X_test1, y_test1, sc1 = Xtrain_ytrain(train,test,10)
# Out:
# X_train Shape : (2374, 10, 5)
# y_train Shape : (2374, 1)
# X_test Shape :  (596, 10, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Add frist layer units = 50 batch size 32  epochs 10

# %%
model_2 = Sequential()
model_2.add(LSTM(units = 50, return_sequences = False, input_shape = (X_train1.shape[1],X_train1.shape[2])))
model_2.add(Dense(units = 1))
model_2.compile(optimizer = 'adam', loss = 'mean_squared_error')
hist1 = model_2.fit(X_train1, y_train1, validation_data=(X_test1, y_test1), epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 4s 14ms/step - loss: 0.0503 - val_loss: 0.0148
# Epoch 2/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 3/20
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0124 - val_loss: 0.0113
# Epoch 4/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0103
# Epoch 5/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0093
# Epoch 6/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 7/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 8/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 9/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 10/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0070
# Epoch 11/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 12/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0066
# Epoch 13/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0076
# Epoch 14/20
# 75/75 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0065
# Epoch 15/20
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 16/20
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 17/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 18/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 19/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 20/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0066

# %%
plot_curve(hist1)

# %%
predict_scaled1 = model_2.predict(X_test1)
predict1 = sc1.inverse_transform(predict_scaled1)
# Out:
# 19/19 [==============================] - 1s 3ms/step

# %%
test1 = test.copy()
train1 = train.copy()

# %%
train1.reset_index(inplace=True)
test1.reset_index(inplace=True)

# %%
test1['LSTM'] = predict1
test1
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.622540
# 1          0.654  0.593227
# 2          0.588  0.627197
# 3          0.577  0.571277
# 4          0.554  0.550196
# ..           ...       ...
# 591        0.185  0.170204
# 592        0.182  0.174850
# 593        0.180  0.171391
# 594        0.169  0.170913
# 595        0.147  0.162732
#
# [596 rows x 7 columns]

# %%
plot_test(train1,test1)

# %%
lstm_mae_error1 = mae(test1["cloud_cover"], test1["LSTM"])
lstm_mape_error1 = mape(test1["cloud_cover"], test1["LSTM"])
lstm_mse_error1 = mean_squared_error(test1['cloud_cover'], test1['LSTM'], squared=True)
lstm_rmse_error1 = mean_squared_error(test1["cloud_cover"], test1["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error1)
print('MAPE Error :  %.5f'%lstm_mape_error1)
print('MSE Error : %.5f'%lstm_mse_error1)
print('RMSE Error :  %.5f'%lstm_rmse_error1)
# Out:
# MAE Error :  0.04798
# MAPE Error :  0.18543
# MSE Error : 0.00651
# RMSE Error :  0.08070

# %% [markdown]
# ---

# %% [markdown]
# ## Lag 15

# %%
# X_train, y_train, X_test and y_test
X_train2, y_train2, X_test2, y_test2, sc2 = Xtrain_ytrain(train,test,15)
# Out:
# X_train Shape : (2369, 15, 5)
# y_train Shape : (2369, 1)
# X_test Shape :  (596, 15, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Optimizer adam first layer 50 drop 0.1 second layer50 batch size 32 epochs 10 lr 0.005

# %%
model_3 = Sequential()
model_3.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train2.shape[1],X_train2.shape[2])))
model_3.add(Dropout(0.1))
model_3.add(LSTM(units = 50))
model_3.add(Dense(units = 1))
opt = optimizers.Adam(learning_rate=0.005)
model_3.compile(optimizer = opt, loss = 'mean_squared_error')
hist2 = model_3.fit(X_train2, y_train2, validation_data=(X_test2, y_test2), epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 75/75 [==============================] - 8s 29ms/step - loss: 0.0302 - val_loss: 0.0132
# Epoch 2/10
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0126 - val_loss: 0.0103
# Epoch 3/10
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0096 - val_loss: 0.0080
# Epoch 4/10
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0068
# Epoch 5/10
# 75/75 [==============================] - 2s 25ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 6/10
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0061 - val_loss: 0.0075
# Epoch 7/10
# 75/75 [==============================] - 1s 15ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 8/10
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0053 - val_loss: 0.0067
# Epoch 9/10
# 75/75 [==============================] - 1s 14ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 10/10
# 75/75 [==============================] - 1s 13ms/step - loss: 0.0055 - val_loss: 0.0069

# %%
plot_curve(hist2)

# %%
predict_scaled2 = model_3.predict(X_test2)
predict2 = sc2.inverse_transform(predict_scaled2)
# Out:
# 19/19 [==============================] - 1s 5ms/step

# %%
train2 = train.copy()
test2 = test.copy()

# %%
train2.reset_index(inplace=True)
test2.reset_index(inplace=True)

# %%
test2['LSTM'] = predict2
test2
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.653420
# 1          0.654  0.620507
# 2          0.588  0.658498
# 3          0.577  0.595129
# 4          0.554  0.583164
# ..           ...       ...
# 591        0.185  0.174917
# 592        0.182  0.181298
# 593        0.180  0.180208
# 594        0.169  0.178379
# 595        0.147  0.169726
#
# [596 rows x 7 columns]

# %%
plot_test(train2,test2)

# %%
lstm_mae_error2 = mae(test2["cloud_cover"], test2["LSTM"])
lstm_mape_error2 = mape(test2["cloud_cover"], test2["LSTM"])
lstm_mse_error2 = mean_squared_error(test2['cloud_cover'], test2['LSTM'], squared=True)
lstm_rmse_error2 = mean_squared_error(test2["cloud_cover"], test2["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error2)
print('MAPE Error :  %.5f'%lstm_mape_error2)
print('MSE Error : %.5f'%lstm_mse_error2)
print('RMSE Error :  %.5f'%lstm_rmse_error2)
# Out:
# MAE Error :  0.04841
# MAPE Error :  0.19095
# MSE Error : 0.00679
# RMSE Error :  0.08241

# %% [markdown]
# ---

# %% [markdown]
# ## Lag 20

# %%
# X_train, y_train, X_test and y_test
X_train3, y_train3, X_test3, y_test3, sc3 = Xtrain_ytrain(train,test,20)
# Out:
# X_train Shape : (2364, 20, 5)
# y_train Shape : (2364, 1)
# X_test Shape :  (596, 20, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Optimizer adam first layer 50 batch size 32 epochs 10 lr 0.005

# %%
model_4 = Sequential()
model_4.add(LSTM(units = 50, return_sequences = False, input_shape = (X_train3.shape[1],X_train3.shape[2])))
model_4.add(Dense(units = 1))
opt = optimizers.Adam(learning_rate=0.005)
model_4.compile(optimizer = opt, loss = 'mean_squared_error')
hist3 = model_4.fit(X_train3, y_train3, validation_data=(X_test3, y_test3), epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 74/74 [==============================] - 4s 20ms/step - loss: 0.0307 - val_loss: 0.0095
# Epoch 2/10
# 74/74 [==============================] - 1s 11ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 3/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0069 - val_loss: 0.0077
# Epoch 4/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 5/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0053 - val_loss: 0.0065
# Epoch 6/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 7/10
# 74/74 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 8/10
# 74/74 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0071
# Epoch 9/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 10/10
# 74/74 [==============================] - 1s 9ms/step - loss: 0.0046 - val_loss: 0.0068

# %%
plot_curve(hist3)

# %%
predict_scaled3 = model_4.predict(X_test3)
predict3 = sc3.inverse_transform(predict_scaled3)
# Out:
# 19/19 [==============================] - 1s 3ms/step

# %%
train3 = train.copy()
test3 = test.copy()

# %%
train3.reset_index(inplace=True)
test3.reset_index(inplace=True)

# %%
test3['LSTM'] = predict3
test3
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.637423
# 1          0.654  0.600290
# 2          0.588  0.640432
# 3          0.577  0.572562
# 4          0.554  0.559481
# ..           ...       ...
# 591        0.185  0.160406
# 592        0.182  0.165262
# 593        0.180  0.162149
# 594        0.169  0.161218
# 595        0.147  0.153698
#
# [596 rows x 7 columns]

# %%
plot_test(train3,test3)

# %%
lstm_mae_error3 = mae(test3["cloud_cover"], test3["LSTM"])
lstm_mape_error3 = mape(test3["cloud_cover"], test3["LSTM"])
lstm_mse_error3 = mean_squared_error(test3['cloud_cover'], test3['LSTM'], squared=True)
lstm_rmse_error3 = mean_squared_error(test3["cloud_cover"], test3["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error3)
print('MAPE Error :  %.5f'%lstm_mape_error3)
print('MSE Error : %.5f'%lstm_mse_error3)
print('RMSE Error :  %.5f'%lstm_rmse_error3)
# Out:
# MAE Error :  0.04853
# MAPE Error :  0.18781
# MSE Error : 0.00673
# RMSE Error :  0.08204

# %% [markdown]
# ---

# %% [markdown]
# ## Lag 25

# %%
# X_train, y_train, X_test and y_test
X_train4, y_train4, X_test4, y_test4, sc4 = Xtrain_ytrain(train,test,25)
# Out:
# X_train Shape : (2359, 25, 5)
# y_train Shape : (2359, 1)
# X_test Shape :  (596, 25, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Optimizer adam first layer 50 batch size 32 learning rate 0.1 epochs 10

# %%
model_5 = Sequential()
model_5.add(LSTM(units = 50, return_sequences = False, input_shape = (X_train4.shape[1],X_train4.shape[2])))
model_5.add(Dense(units = 1))
opt = optimizers.Adam(learning_rate=0.1)
model_5.compile(optimizer = opt, loss = 'mean_squared_error')
hist4 = model_5.fit(X_train4, y_train4, validation_data=(X_test4, y_test4), epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 74/74 [==============================] - 4s 22ms/step - loss: 0.8866 - val_loss: 0.0076
# Epoch 2/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0054 - val_loss: 0.0108
# Epoch 3/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0052 - val_loss: 0.0079
# Epoch 4/10
# 74/74 [==============================] - 1s 14ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 5/10
# 74/74 [==============================] - 1s 12ms/step - loss: 0.0050 - val_loss: 0.0080
# Epoch 6/10
# 74/74 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0084
# Epoch 7/10
# 74/74 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 8/10
# 74/74 [==============================] - 1s 15ms/step - loss: 0.0058 - val_loss: 0.0096
# Epoch 9/10
# 74/74 [==============================] - 1s 12ms/step - loss: 0.0057 - val_loss: 0.0094
# Epoch 10/10
# 74/74 [==============================] - 1s 14ms/step - loss: 0.0059 - val_loss: 0.0074

# %%
plot_curve(hist4)

# %%
predict_scaled4 = model_5.predict(X_test4)
predict4 = sc4.inverse_transform(predict_scaled4)
# Out:
# 19/19 [==============================] - 1s 4ms/step

# %%
train4 = train.copy()
test4 = test.copy()

# %%
train4.reset_index(inplace=True)
test4.reset_index(inplace=True)

# %%
test4['LSTM'] = predict4
test4
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.648794
# 1          0.654  0.574958
# 2          0.588  0.655024
# 3          0.577  0.561195
# 4          0.554  0.558209
# ..           ...       ...
# 591        0.185  0.172983
# 592        0.182  0.182322
# 593        0.180  0.178576
# 594        0.169  0.176452
# 595        0.147  0.168009
#
# [596 rows x 7 columns]

# %%
plot_test(train4,test4)

# %%
lstm_mae_error4 = mae(test4["cloud_cover"], test4["LSTM"])
lstm_mape_error4 = mape(test4["cloud_cover"], test4["LSTM"])
lstm_mse_error4 = mean_squared_error(test4['cloud_cover'], test4['LSTM'], squared=True)
lstm_rmse_error4 = mean_squared_error(test4["cloud_cover"], test4["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error4)
print('MAPE Error :  %.5f'%lstm_mape_error4)
print('MSE Error : %.5f'%lstm_mse_error4)
print('RMSE Error :  %.5f'%lstm_rmse_error4)
# Out:
# MAE Error :  0.05126
# MAPE Error :  0.18725
# MSE Error : 0.00735
# RMSE Error :  0.08571

# %% [markdown]
# ---

# %% [markdown]
# ## Lag 30

# %%
# X_train, y_train, X_test and y_test
X_train5, y_train5, X_test5, y_test5, sc5 = Xtrain_ytrain(train,test,30)
# Out:
# X_train Shape : (2354, 30, 5)
# y_train Shape : (2354, 1)
# X_test Shape :  (596, 30, 5)
# y_test Shape :  (596, 1)

# %% [markdown]
# ### Add frist layer units = 100 batch size 32  epochs 10 lr 0.005

# %%
model_6 = Sequential()
model_6.add(LSTM(units = 100, return_sequences = False, input_shape = (X_train5.shape[1],X_train5.shape[2])))
model_6.add(Dense(units = 1))
opt = optimizers.Adam(learning_rate=0.005)
model_6.compile(optimizer = opt, loss = 'mean_squared_error')
hist5 = model_6.fit(X_train5, y_train5, validation_data=(X_test5, y_test5), epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 74/74 [==============================] - 6s 36ms/step - loss: 0.0189 - val_loss: 0.0092
# Epoch 2/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 3/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0063 - val_loss: 0.0072
# Epoch 4/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 5/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 6/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 7/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0047 - val_loss: 0.0069
# Epoch 8/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0047 - val_loss: 0.0069
# Epoch 9/10
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0047 - val_loss: 0.0071
# Epoch 10/10
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0048 - val_loss: 0.0071

# %%
plot_curve(hist5)

# %%
predict_scaled5 = model_6.predict(X_test5)
predict5 = sc5.inverse_transform(predict_scaled5)
# Out:
# 19/19 [==============================] - 1s 7ms/step

# %%
train5 = train.copy()
test5 = test.copy()

# %%
train5.reset_index(inplace=True)
test5.reset_index(inplace=True)

# %%
test5['LSTM'] = predict5
test5
# Out:
#                 DateTime       Eeg  Temperature       RH  Windspeed  \
# 0    2021-12-10 15:15:00  405.4060     30.62860  49.2608     1.6896
# 1    2021-12-10 15:20:00  439.9825     30.41125  50.1080     1.7555
# 2    2021-12-10 15:25:00  506.7830     30.81500  49.5100     1.7740
# 3    2021-12-10 15:30:00  482.9326     30.50740  50.0562     1.6948
# 4    2021-12-10 15:35:00  399.8080     30.35780  50.8378     1.7424
# ..                   ...       ...          ...      ...        ...
# 591  2021-12-16 13:40:00  667.8462     32.06380  38.0598     1.7466
# 592  2021-12-16 13:45:00  655.7560     32.39060  37.1100     1.7442
# 593  2021-12-16 13:50:00  647.5236     32.34440  37.1282     1.7116
# 594  2021-12-16 13:55:00  635.4336     32.39440  37.2276     1.7612
# 595  2021-12-16 14:00:00  623.2140     32.87800  36.3920     1.7566
#
#      cloud_cover      LSTM
# 0          0.601  0.668125
# 1          0.654  0.620625
# 2          0.588  0.667288
# 3          0.577  0.597543
# 4          0.554  0.584381
# ..           ...       ...
# 591        0.185  0.199104
# 592        0.182  0.204530
# 593        0.180  0.200917
# 594        0.169  0.199120
# 595        0.147  0.191198
#
# [596 rows x 7 columns]

# %%
plot_test(train5,test5)

# %%
lstm_mae_error5 = mae(test5["cloud_cover"], test5["LSTM"])
lstm_mape_error5 = mape(test5["cloud_cover"], test5["LSTM"])
lstm_mse_error5 = mean_squared_error(test5['cloud_cover'], test5['LSTM'], squared=True)
lstm_rmse_error5 = mean_squared_error(test5["cloud_cover"], test5["LSTM"], squared=False)
print('MAE Error :  %.5f'%lstm_mae_error5)
print('MAPE Error :  %.5f'%lstm_mape_error5)
print('MSE Error : %.5f'%lstm_mse_error5)
print('RMSE Error :  %.5f'%lstm_rmse_error5)
# Out:
# MAE Error :  0.05116
# MAPE Error :  0.23256
# MSE Error : 0.00708
# RMSE Error :  0.08412

# %% [markdown]
# ---

# %% [markdown]
# # error

# %% [markdown]
# ## avg mae

# %%
avgmse = (lstm_mae_error+lstm_mae_error1+lstm_mae_error2+lstm_mae_error3+lstm_mae_error4+lstm_mae_error5)/6
print("AVG MAE : %.5f"%avgmse)
# Out:
# AVG MAE : 0.04907

# %% [markdown]
# ---

# %% [markdown]
# ## avg mape

# %%
avgmape = (lstm_mape_error+lstm_mape_error1+lstm_mape_error2+lstm_mape_error3+lstm_mape_error4+lstm_mape_error5)/6
print("AVG MAPE : %.5f"%avgmape)
# Out:
# AVG MAPE : 0.19398

# %% [markdown]
# ---

# %% [markdown]
# ## avg mse

# %%
avgmse = (lstm_mse_error+lstm_mse_error1+lstm_mse_error2+lstm_mse_error3+lstm_mse_error4+lstm_mse_error5)/6
print("AVG MSE :%.5f"%avgmse)
# Out:
# AVG MSE :0.00686

# %% [markdown]
# ---

# %% [markdown]
# ## avg rmse

# %%
avgrmse = (lstm_rmse_error+lstm_rmse_error1+lstm_rmse_error2+lstm_rmse_error3+lstm_rmse_error4+lstm_rmse_error5)/6
print("AVG RMSE : %.5f"%avgrmse)
# Out:
# AVG RMSE : 0.08279

# %% [markdown]
# ---

# %% [markdown]
# ---
